# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
from sklearn.metrics import precision_recall_curve,f1_score,accuracy_score,mean_absolute_error,mean_absolute_percentage_error,root_mean_squared_error,mean_squared_error,confusion_matrix,classification_report
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,OrdinalEncoder,RobustScaler,MinMaxScaler,StandardScaler
df=sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
categoric_cols=['cut','clarity','color']
#using label ecnoder
encoder=LabelEncoder()
for col in categoric_cols:
    df[col]=encoder.fit_transform(df[col])
    
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data_with_outliers=['depth','table','x','y','z']
robust=RobustScaler()
for col_2 in data_with_outliers:
    df[col_2]=robust.fit_transform(df[[col_2]])
df
# Out:
#        carat  cut  color  clarity     depth     table  price         x  \
# 0       0.23    2      1        3 -0.200000 -0.666667    326 -0.956284
# 1       0.21    3      1        2 -1.333333  1.333333    326 -0.989071
# 2       0.23    1      1        4 -3.266667  2.666667    327 -0.901639
# 3       0.29    3      5        5  0.400000  0.333333    334 -0.819672
# 4       0.31    1      6        3  1.000000  0.333333    335 -0.743169
# ...      ...  ...    ...      ...       ...       ...    ...       ...
# 53935   0.72    2      0        2 -0.666667  0.000000   2757  0.027322
# 53936   0.72    1      0        2  0.866667 -0.666667   2757 -0.005464
# 53937   0.70    4      0        2  0.666667  1.000000   2757 -0.021858
# 53938   0.86    3      4        3 -0.533333  0.333333   2757  0.245902
# 53939   0.75    2      0        3  0.266667 -0.666667   2757  0.071038
#
#               y         z
# 0     -0.950549 -0.973451
# 1     -1.027473 -1.079646
# 2     -0.901099 -1.079646
# ...

# %%
data_without_outliers=['carat','cut','color','clarity']
ss=StandardScaler()
for col_3 in data_without_outliers:
    df[col_3]=ss.fit_transform(df[[col_3]])
df
# Out:
#           carat       cut     color   clarity     depth     table  price  \
# 0     -1.198168 -0.538099 -0.937163 -0.484264 -0.200000 -0.666667    326
# 1     -1.240361  0.434949 -0.937163 -1.064117 -1.333333  1.333333    326
# 2     -1.198168 -1.511147 -0.937163  0.095589 -3.266667  2.666667    327
# 3     -1.071587  0.434949  1.414272  0.675442  0.400000  0.333333    334
# 4     -1.029394 -1.511147  2.002131 -0.484264  1.000000  0.333333    335
# ...         ...       ...       ...       ...       ...       ...    ...
# 53935 -0.164427 -0.538099 -1.525021 -1.064117 -0.666667  0.000000   2757
# 53936 -0.164427 -1.511147 -1.525021 -1.064117  0.866667 -0.666667   2757
# 53937 -0.206621  1.407998 -1.525021 -1.064117  0.666667  1.000000   2757
# 53938  0.130927  0.434949  0.826413 -0.484264 -0.533333  0.333333   2757
# 53939 -0.101137 -0.538099 -1.525021 -0.484264  0.266667 -0.666667   2757
#
#               x         y         z
# 0     -0.956284 -0.950549 -0.973451
# ...

# %%
X = df.drop('price', axis=1)
y = df['price']

# %%
from pycaret.regression import *

#Using pycaret
# Initialize PyCaret regression setup
regression_setup = setup(data=df, target='price',n_jobs=-3)

# Compare models
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4f1c4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4f1c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f1c4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4f1c4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f1c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f1c4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4f1c4_row0_col1" class="data row0 col1" >7480</td>
#     </tr>
#     <tr>
#       <th id="T_4f1c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f1c4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4f1c4_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_4f1c4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # **This Shuts Pc**

# %%
# model=create_model('et')
# model.set_params(n_jobs=2)

# tuned_model = tune_model(model, optimize='R2', fold=3, n_iter=5)
# Out:
# <style type="text/css">
# #T_f055b_row10_col0, #T_f055b_row10_col1, #T_f055b_row10_col2, #T_f055b_row10_col3, #T_f055b_row10_col4, #T_f055b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f055b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f055b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f055b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f055b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f055b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f055b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f055b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
