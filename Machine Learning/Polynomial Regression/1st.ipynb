# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_percentage_error,mean_absolute_error
import operator

# %%
#create dummy data
#Getting the same random numbers every time
np.random.seed(0) 


#this creates 20 random numbers around 2
x = 2-3*np.random.normal(0,1,20)  


# This line creates y values using a non-linear formula
y = x-2*(x**2)+np.random.normal(-3,3,20)

#Reshaping the model
x=x[:,np.newaxis]
y=y[:,np.newaxis]

# %%
# polynomial transformation
poly = PolynomialFeatures(degree=1)
x_poly = poly.fit_transform(x)

model=LinearRegression()
model.fit(x_poly,y)

y_poly_pred=model.predict(x_poly)

#evaluate the model
print(model.score(x_poly,y))
print('MSE',mean_squared_error(y,y_poly_pred))
print('R2',r2_score(y,y_poly_pred))
print('MAPE',mean_absolute_percentage_error(y,y_poly_pred))
print('MAE',mean_absolute_error(y,y_poly_pred))

plt.scatter(x, y, color='blue')
sns.lineplot(x=x.flatten(),y=y_poly_pred.flatten(),color='magenta')

plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# 0.010009603077459683
# MSE 264.7333784538786
# R2 0.010009603077459683
# MAPE 2.4057028094686266
# MAE 12.707910059939305

# %%
'''# Scatter plot of actual data
plt.scatter(x, y, color='blue')

# Sorting x and predicted y values by x for smooth plotting
sorted_zip = sorted(zip(x, y_poly_pred), key=operator.itemgetter(0))
x_sorted, y_pred_sorted = zip(*sorted_zip)

# Plotting the regression curve
plt.plot(x_sorted, y_pred_sorted, color='magenta')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()




                           SAME IN 2 LINES
                           
plt.scatter(x, y, color='blue')
sns.lineplot(x=x.flatten(),y=y_poly_pred.flatten(),color='magenta')


plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

'''
# Out:
# "# Scatter plot of actual data\nplt.scatter(x, y, color='blue')\n\n# Sorting x and predicted y values by x for smooth plotting\nsorted_zip = sorted(zip(x, y_poly_pred), key=operator.itemgetter(0))\nx_sorted, y_pred_sorted = zip(*sorted_zip)\n\n# Plotting the regression curve\nplt.plot(x_sorted, y_pred_sorted, color='magenta')\nplt.title('Polynomial Regression')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.show()\n\n\n\n\n                           SAME IN 2 LINES\n                           \nplt.scatter(x, y, color='blue')\nsns.lineplot(x=x.flatten(),y=y_poly_pred.flatten(),color='magenta')\n\n\nplt.title('Polynomial Regression')\nplt.xlabel('X')\nplt.ylabel('Y')\nplt.show()\n\n"

# %%
# polynomial transformation
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

model=LinearRegression()
model.fit(x_poly,y)

y_poly_pred=model.predict(x_poly)

#evaluate the model
print(model.score(x_poly,y))
print('MSE',mean_squared_error(y,y_poly_pred))
print('R2',r2_score(y,y_poly_pred))
print('MAPE',mean_absolute_percentage_error(y,y_poly_pred))
print('MAE',mean_absolute_error(y,y_poly_pred))

plt.scatter(x, y, color='blue')
sns.lineplot(x=x.flatten(),y=y_poly_pred.flatten(),color='magenta')

plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# 0.9554314660552853
# MSE 11.918073751622313
# R2 0.9554314660552853
# MAPE 0.4485698687312862
# MAE 2.6341065518757225
