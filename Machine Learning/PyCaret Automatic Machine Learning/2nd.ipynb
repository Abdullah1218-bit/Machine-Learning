# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
#import catboost
from pycaret.datasets import get_data
index= get_data('index')
from pycaret.classification import *
juice = get_data('juice')
clf1 = setup(data=juice, target='Purchase', session_id=123, log_experiment=False, experiment_name='juice_classification')
compare_models()
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# # **Interpret Model**

# %%
random_forest= create_model('rf',cross_validation=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0e2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0e2f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b0e2f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b0e2f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b0e2f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b0e2f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b0e2f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b0e2f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0e2f_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_b0e2f_row0_col0" class="data row0 col0" >0.8162</td>
#       <td id="T_b0e2f_row0_col1" class="data row0 col1" >0.8884</td>
# ...

# %%
interpret_model(random_forest)

# %%
interpret_model(random_forest, plot='correlation')

# %%
interpret_model(random_forest,plot='reason', observation=12)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# # ****AutoML()****

# %%
best=automl(optimize='Recall')
best
# Out:
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)
